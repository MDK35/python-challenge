# %%
# Import depedancies 
import csv 
import os 

# loading and output of csv
fileload = os.path.join(".", "Resources", "election_data.csv")

fileoutput = os.path.join(".", "election_analysis.txt")

#vote counter
total_votes = 0


#store values into a list for candidate data
canvotes = {}
canoptions = []

#winning candidate count and tracker
wincan = ""
wincount = 0

with open(fileload) as election_d:
    
    scanner = csv.reader(election_d)
    
    #reading the header
    column = next(scanner)
#     print(column) - print the header of the csv
    
    
    for row in scanner:
        # adding to the total vote count 
        total_votes = total_votes + 1   
    
        # Get the candidates name from each row
        canname = row[2]
        
        
#         if candidate does not match , it will loop through until it does

        if canname not in canoptions:
        
        # Add list of running candidates
                    canoptions.append(canname)
            
                    canvotes[canname] = 0
            
        canvotes[canname] += 1
            
# print(canvotes)

# print(canoptions)
    
    
with open (fileoutput, "w") as txt_file:   
    election_statistics = (
        f"Election Results !!\n"
        f"~~~~~~~~~~~~~~~~~~~~~~~\n" 
        f"Total Votes: {total_votes}\n"
        f"~~~~~~~~~~~~~~~~~~~~~~~~\n" 


    )

    print(election_statistics)    



    txt_file.write(election_statistics)
    
    # loop for running through candidate votes and getting a percentage
    for candidate in canvotes:
        
        votes = canvotes[candidate]
        vote_percent = float(votes)/float(total_votes) * 100
       
    
        if(votes > wincount):
            wincount = votes
            wincan = candidate
            
            
            
        voter_display = f"{candidate}: {vote_percent:.3f}% ({votes})\n"
        
#         print(votes) - individual voter percentage
#         print(vote_percent)
        
        print(voter_output)
        
        txt_file.write(voter_display)
      # print winner results  
    wincan_result = (
        f"~~~~~~~~~~~~~~~~~~~~~~~\n"
        f" Winnner: {wincan}\n"
        f"~~~~~~~~~~~~~~~~~~~~~~~\n"
        f"Congratulations !!\n"
    
    )
    print(wincan_result)
    txt_file.write(wincan_result)
    
    

# Election Results
# -------------------------
# Total Votes: 369711
# -------------------------
# Charles Casper Stockham: 23.049% (85213)
# Diana DeGette: 73.812% (272892)
# Raymon Anthony Doane: 3.139% (11606)
# -------------------------
# Winner: Diana DeGette
# -------------------------
# Out:
# Election Results !!
# ~~~~~~~~~~~~~~~~~~~~~~~
# Total Votes: 369711
# ~~~~~~~~~~~~~~~~~~~~~~~~
#
# Charles Casper Stockham: 23.049% (85213)
#
# Diana DeGette: 73.812% (272892)
#
# Raymon Anthony Doane: 3.139% (11606)
#
# ~~~~~~~~~~~~~~~~~~~~~~~
#  Winnner: Diana DeGette
# ~~~~~~~~~~~~~~~~~~~~~~~
# Congratulations !!
